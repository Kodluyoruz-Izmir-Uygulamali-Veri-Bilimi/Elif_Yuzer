# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv("train.csv")
display(titanic.head(5))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Label Encoding

# %% [markdown]
# Sex değişkenini Mean encoding yaparak encode ediniz. Her kategori için Survived değişkeninin ortalamasını kategori adı ile değiştirebilirsiniz.
#
# IPUCU: pandas groupby ve map fonksiyonlarını kullanabilirsiniz.

# %%
#python kodu buraya
titanic.groupby(['Sex'])['Survived'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Survived, dtype: int64

# %%
titanic.groupby(['Sex'])['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
mean_encoded_sex = titanic.groupby(['Sex'])['Survived'].mean().to_dict() 
titanic['Sex'] =  titanic['Sex'].map(mean_encoded_sex) 
display(titanic)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name       Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  0.188908  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  0.742038  38.0      1
# 2                               Heikkinen, Miss. Laina  0.742038  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.742038  35.0      1
# 4                             Allen, Mr. William Henry  0.188908  35.0      0
# ..                                                 ...       ...   ...    ...
# 886                              Montvila, Rev. Juozas  0.188908  27.0      0
# 887                       Graham, Miss. Margaret Edith  0.742038  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  0.742038   NaN      1
# 889                              Behr, Mr. Karl Howell  0.188908  26.0      0
# 890                                Dooley, Mr. Patrick  0.188908  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# Bindikleri Yer (Embarked) değişkenini sklearn OneHotEncoder objesini kullanarak encode edin.<br>

# %%
#python kodu buraya
from sklearn.preprocessing import OneHotEncoder
titanic_onehotencoder= pd.get_dummies(titanic,columns=['Embarked'])
display(titanic_onehotencoder)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name       Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  0.188908  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  0.742038  38.0      1
# 2                               Heikkinen, Miss. Laina  0.742038  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.742038  35.0      1
# 4                             Allen, Mr. William Henry  0.188908  35.0      0
# ..                                                 ...       ...   ...    ...
# 886                              Montvila, Rev. Juozas  0.188908  27.0      0
# 887                       Graham, Miss. Margaret Edith  0.742038  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  0.742038   NaN      1
# 889                              Behr, Mr. Karl Howell  0.188908  26.0      0
# 890                                Dooley, Mr. Patrick  0.188908  32.0      0
#
#      Parch            Ticket     Fare Cabin  Embarked_C  Embarked_Q  \
# 0        0         A/5 21171   7.2500   NaN           0           0
# 1        0          PC 17599  71.2833   C85           1           0
# 2        0  STON/O2. 3101282   7.9250   NaN           0           0
# 3        0            113803  53.1000  C123           0           0
# 4        0            373450   8.0500   NaN           0           0
# ..     ...               ...      ...   ...         ...         ...
# 886      0            211536  13.0000   NaN           0           0
# 887      0            112053  30.0000   B42           0           0
# 888      2        W./C. 6607  23.4500   NaN           0           0
# 889      0            111369  30.0000  C148           1           0
# 890      0            370376   7.7500   NaN           0           1
#
#      Embarked_S
# 0             1
# 1             0
# 2             1
# 3             1
# 4             1
# ..          ...
# 886           1
# 887           1
# 888           1
# 889           0
# 890           0
#
# [891 rows x 14 columns]

# %% [markdown]
# Cabin değişkenini sklearn LabelEncoder veya OrdinalEncoder objesini kullanarak encode edin.

# %%
#python kodu buraya
from sklearn.preprocessing import LabelEncoder
titanic['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
titanic.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %%
titanic[['Cabin']].astype(str)
# Out:
#     Cabin
# 0     nan
# 1     C85
# 2     nan
# 3    C123
# 4     nan
# ..    ...
# 886   nan
# 887   B42
# 888   nan
# 889  C148
# 890   nan
#
# [891 rows x 1 columns]

# %%
titanic[['Cabin']] =titanic[['Cabin']].astype(str)

# %%
lbe=LabelEncoder()
titanic['Cabin']= lbe.fit_transform(titanic['Cabin'])
display(titanic)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name       Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  0.188908  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  0.742038  38.0      1
# 2                               Heikkinen, Miss. Laina  0.742038  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.742038  35.0      1
# 4                             Allen, Mr. William Henry  0.188908  35.0      0
# ..                                                 ...       ...   ...    ...
# 886                              Montvila, Rev. Juozas  0.188908  27.0      0
# 887                       Graham, Miss. Margaret Edith  0.742038  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  0.742038   NaN      1
# 889                              Behr, Mr. Karl Howell  0.188908  26.0      0
# 890                                Dooley, Mr. Patrick  0.188908  32.0      0
#
#      Parch            Ticket     Fare  Cabin Embarked
# 0        0         A/5 21171   7.2500    147        S
# 1        0          PC 17599  71.2833     81        C
# 2        0  STON/O2. 3101282   7.9250    147        S
# 3        0            113803  53.1000     55        S
# 4        0            373450   8.0500    147        S
# ..     ...               ...      ...    ...      ...
# 886      0            211536  13.0000    147        S
# 887      0            112053  30.0000     30        S
# 888      2        W./C. 6607  23.4500    147        S
# 889      0            111369  30.0000     60        C
# 890      0            370376   7.7500    147        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # Outlier Handling

# %% [markdown]
# Fare değişkeni için boxplot çizdiriniz.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#python kodu buraya
sns.boxplot(titanic["Fare"])

# %% [markdown]
# Fare değişkeninedeki outlier değerleri Z-Score kullanarak tespit ediniz, sınır değerlerini ve kaç tane outlier değer olduğunu yazdırınız.

# %%
#python kodu buraya
from scipy import stats
titanic_zscore=titanic.copy()
up=titanic_zscore.Fare.max()
low=titanic_zscore.Fare.min()

# %%
print(low)
print(up)
# Out:
# 0.0
# 512.3292

# %%
titanic_zscore["Fare"].sum()
# Out:
# 28693.9493

# %% [markdown]
# Tespit ettiğiniz outlier'ları sınır değerler ile değiştiriniz.

# %%
#python kodu buraya

# %% [markdown]
# Fare değişkeninedeki outlier değerleri IQR metodunu kullanarak tespit ediniz, sınır değerlerini ve kaç tane outlier değer olduğunu yazdırınız.

# %%
#python kodu buraya
q1 = titanic["Fare"].quantile(q=0.25)
q3 = titanic["Fare"].quantile(q=0.75)

# %%
iqr = q3-q1
iqr
# Out:
# 23.0896

# %%
upper_limit = q3 + 1.5*iqr
lower_limit = q1 - 1.5*iqr
lower_limit, upper_limit
# Out:
# (-26.724, 65.6344)

# %% [markdown]
# Tespit ettiğiniz outlier'ları sınır değerler ile değiştiriniz.

# %%
#python kodu buraya

# %% [markdown]
# Fare değişkeninedeki outlier değerleri Hard-Edges metodunu kullanarak tespit ediniz, sınır değerlerini ve kaç tane outlier değer olduğunu yazdırınız.

# %%
#python kodu buraya
titanic_hardedges=titanic.copy()

# %%
lower_limit = titanic_hardedges["Fare"].quantile(q=0.01)
upper_limit = titanic_hardedges["Fare"].quantile(q=0.99)
upper_limit, lower_limit
# Out:
# (249.00622000000033, 0.0)

# %% [markdown]
# Tespit ettiğiniz outlier'ları sınır değerler ile değiştiriniz.

# %%
#python kodu buraya
titanic_hardedges["Fare"][titanic["Fare"] > upper_limit] = upper_limit
titanic_hardedges["Fare"][titanic["Fare"]< lower_limit] = lower_limit
# Out:
# <ipython-input-65-5f5b069aa316>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_hardedges["Fare"][titanic["Fare"] > upper_limit] = upper_limit
# <ipython-input-65-5f5b069aa316>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_hardedges["Fare"][titanic["Fare"]< lower_limit] = lower_limit

# %% [markdown]
# Fare değişkeni için yukarıdaki 3 metodu kullanarak sınır değerler olarak bulduğunuz değerleri ve outlier sayılarını karşılaştırın. Bu değişken için hangisini kullanmak daha mantıklı olabilir?
